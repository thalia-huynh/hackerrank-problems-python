# %% [markdown]
# ### Weather Observation Station 4

# %% [markdown]
# ![Screen%20Shot%202023-02-09%20at%2010.52.39%20AM.png](attachment:Screen%20Shot%202023-02-09%20at%2010.52.39%20AM.png)

# %% [markdown]
# select count(city) - count(distinct(city))<br>
# from station;

# %% [markdown]
# ### Weather Observation Station 5

# %% [markdown]
# ![Alt text](Screen%20Shot%202023-02-13%20at%2010.47.54%20AM.png)

# %% [markdown]
# select city, length(city)<br>
# from station<br>
# order by length(city) asc, city asc<br>
# limit 1;<br>
# select city, length(city)<br>
# from station<br>
# order by length(city desc), city asc<br>
# limit 1;<br>
